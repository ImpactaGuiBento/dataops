# %%
import mysql.connector
import pandas as pd
import os
from sqlalchemy import create_engine

# %%
con = mysql.connector.connect(
            user='root', 
            # password=os.environ['DB_PASSWORD'], 
            port="3306", 
            host = 'localhost', 
            database='db'
            )

# %%
query = """
SELECT * FROM db.cadastro;
"""

# %%
pd.read_sql(query, con)
# Out:
# /tmp/ipykernel_11367/1605690232.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(query, con)
#    id    sexo titulo      nome  sobrenome                cidade  \
# 0   1    male     Mr    elliot   kjeldsen                    bø
# 1   2    male     Mr  jerónimo      mateo  tamazula de victoria
# 2   3    male     Mr   mohamud  de fijter         lichtenvoorde
# 3   4    male     Mr    melvin    andrews               modesto
# 4   5    male     Mr    ostoja      erceg             leposavić
# 5   6  female   Miss   sanjana       kini                nagaon
# 6   7  female     Ms    claire  mcdonalid             busselton
# 7   8    male     Mr    kasper      olsen            juelsminde
# 8   9    male     Mr   alberto      gomez                cairns
# 9  10    male     Mr   vitryan  berezhniy               alushta
#
#              estado           pais nacionalidade                       email  \
# 0         austagder         norway            no    elliotkjeldsenexamplecom
# 1  ciudad de mexico         mexico            mx     jeronimomateoexamplecom
# 2      noordholland    netherlands            nl   mohamuddefijterexamplecom
# 3          illinois  united states            us     melvinandrewsexamplecom
# 4           toplica         serbia            rs       ostojaercegexamplecom
# 5     daman and diu          india            in       sanjanakiniexamplecom
# 6   new south wales      australia            au   clairemcdonalidexamplecom
# 7       hovedstaden        denmark            dk       kasperolsenexamplecom
# 8   south australia      australia            au      albertogomezexamplecom
# 9          luganska        ukraine            ua  vitryanberezhniyexamplecom
#
#   data_nascimento    telefone     celular  load_date
# 0      1975-01-05    70352708    91492293 2024-04-28
# 1      1956-03-10  6187454165  6420189448 2024-04-28
# 2      1992-05-22   668261982   609293706 2024-04-28
# 3      1998-04-19  7028184518  8946061473 2024-04-28
# 4      1991-10-01   366123336   666036025 2024-04-28
# 5      1950-07-16  7301577697  8593658905 2024-04-28
# 6      1955-02-19   671349749   439470569 2024-04-28
# 7      1951-06-24    96113856    39659515 2024-04-28
# 8      1948-10-17   561741621   477525651 2024-04-28
# 9      1959-02-22    97706666    99392959 2024-04-28
